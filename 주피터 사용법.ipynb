# %% [markdown]
# # Jupyter Tutorial
# ## 1. What is Jupyter Notebook?

# %% [markdown]
# The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations.

# %% [markdown]
# ## 2. Live Code Example

# %%
def add(a, b):
    return a + b

# %%
add(5, 4)
# Out:
# 9

# %% [markdown]
# ## 3. Equation

# %%
# sqrt(x^2 + y^2 + z^2)

# %% [markdown]
# This expresstion $\sqrt{x^2 + y^2 + x^2}$ is an example of a TeX inline equation.

# %% [markdown]
# [More Examples click here](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html)

# %% [markdown]
# ## 4. Visualization

# %% [markdown]
# ### 4.1 image

# %%
from IPython.display import Image

Image(url = "https://raw.githubusercontent.com/jupyter/jupyter/master/docs/source/_static/_images/jupyter.png", width = 400, height = 100)
# Out:
# <img src="https://raw.githubusercontent.com/jupyter/jupyter/master/docs/source/_static/_images/jupyter.png" width="400" height="100"/>

# %% [markdown]
# ### 4.2 video

# %%
from IPython.display import YouTubeVideo 

YouTubeVideo("GHHNF5S_TAI")

# %% [markdown]
# ### 4.3 table

# %%
import pandas as pd

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
pd.read_csv(url, nrows=10)
# Out:
#                     Country  Region
# 0                   Algeria  AFRICA
# 1                    Angola  AFRICA
# 2                     Benin  AFRICA
# 3                  Botswana  AFRICA
# 4                   Burkina  AFRICA
# 5                   Burundi  AFRICA
# 6                  Cameroon  AFRICA
# 7                Cape Verde  AFRICA
# 8  Central African Republic  AFRICA
# 9                      Chad  AFRICA

# %% [markdown]
# ### 4.4 chart

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# ## 5. Performance check

# %%
# %timeit 3 + 4
# Out:
# 13.9 ns ± 0.49 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
# %timeit add(3, 4)
# Out:
# 159 ns ± 7.69 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %%timeit
a = [1, 2, 3]
a = [x + 1 for x in a]
# Out:
# 610 ns ± 45.1 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit
b = [1, 2, 3]
for i in range(len(b)):
    b[i] = b[i] + 1
# Out:
# 1.05 µs ± 43.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
